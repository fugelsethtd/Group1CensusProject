# %%
API_Key = "89794a866a41f468f02718b317bb9dbaaf31054b"

import requests
import json
import pandas as pd
HOST = "https://api.census.gov/data"
dataset1 = "2018/abscs?"
parameters1 = "get=GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,VET_GROUP,VET_GROUP_LABEL,EMPSZFI,EMPSZFI_LABEL,YEAR,FIRMPDEMP,FIRMPDEMP_F,RCPPDEMP,RCPPDEMP_F,EMP,EMP_F,PAYANN,PAYANN_F,FIRMPDEMP_S,FIRMPDEMP_S_F,RCPPDEMP_S,RCPPDEMP_S_F,EMP_S,EMP_S_F,PAYANN_S,PAYANN_S_F&for=us:"

base_url = "/".join([HOST, dataset1])

predicates = {}

get_vars = ["GEO_ID","NAME","SEX","ETH_GROUP"]

predicates['get'] = ",".join(get_vars)
predicates['for'] = "us"
r = requests.get(base_url, params=predicates)

print(r.text)
print(r.json()[0])

col_names = ["geo_id","name","sex","ethnic_group","us"]

df = pd.DataFrame(columns=col_names, data=r.json()[1:])

df["ethnic_group"] = df["ethnic_group"].astype(int)
df["sex"] = df["sex"].astype(int)
df["us"] = df["us"].astype(int)
print(df.head(20))
# response = requests.get("https://api.census.gov/data/2018/abscs.html")
# print(response.status_code)

# %%
data = requests.get(GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,VET_GROUP,VET_GROUP_LABEL,EMPSZFI,EMPSZFI_LABEL,YEAR,FIRMPDEMP,FIRMPDEMP_F,RCPPDEMP,RCPPDEMP_F,EMP,EMP_F,PAYANN,PAYANN_F,FIRMPDEMP_S,FIRMPDEMP_S_F,RCPPDEMP_S,RCPPDEMP_S_F,EMP_S,EMP_S_F,PAYANN_S,PAYANN_S_F&for=us:*&key=API_Key)

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

HOST = "https://api.census.gov/data"
dataset1 = "2018/abscs?"
parameters1 = "get=GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,VET_GROUP,VET_GROUP_LABEL,EMPSZFI,EMPSZFI_LABEL,YEAR,FIRMPDEMP,FIRMPDEMP_F,RCPPDEMP,RCPPDEMP_F,EMP,EMP_F,PAYANN,PAYANN_F,FIRMPDEMP_S,FIRMPDEMP_S_F,RCPPDEMP_S,RCPPDEMP_S_F,EMP_S,EMP_S_F,PAYANN_S,PAYANN_S_F&for=us:"

base_url = "/".join([HOST, dataset1])

predicates = {}

get_vars = ["SEX","SEX_LABEL","PAYANN"]

predicates['get'] = ",".join(get_vars)
predicates['for'] = "us"
r = requests.get(base_url, params=predicates)

# print(r.text)
# print(r.json()[0])

col_names = ["sex","sex_label","annual_payroll","us"]

df = pd.DataFrame(columns=col_names, data=r.json()[1:])

df["sex"] = df["sex"].astype(int)
df["annual_payroll"] = df["annual_payroll"].astype(float)
df["us"] = df["us"].astype(int)
print(df.head())
gender_payrolls = df[['sex_label','annual_payroll']]
gender_payrolls.plot.bar(x = 'sex_label', y = 'annual_payroll')
# plt.plot(df['sex_label'],df['annual_payroll'])
plt.title('Total Payroll for Businesses based on Gender of Owner')
plt.xlabel('Gender')
plt.ylabel('Annual Payroll (Scientific Notation)')
plt.show()

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

HOST = "https://api.census.gov/data"
dataset1 = "2018/abscs?"
parameters1 = "get=GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,VET_GROUP,VET_GROUP_LABEL,EMPSZFI,EMPSZFI_LABEL,YEAR,FIRMPDEMP,FIRMPDEMP_F,RCPPDEMP,RCPPDEMP_F,EMP,EMP_F,PAYANN,PAYANN_F,FIRMPDEMP_S,FIRMPDEMP_S_F,RCPPDEMP_S,RCPPDEMP_S_F,EMP_S,EMP_S_F,PAYANN_S,PAYANN_S_F&for=us:"

base_url = "/".join([HOST, dataset1])

predicates = {}

get_vars = ["SEX","SEX_LABEL","EMP"]

predicates['get'] = ",".join(get_vars)
predicates['for'] = "us"
r = requests.get(base_url, params=predicates)

# print(r.text)
# print(r.json()[0])

col_names = ["sex","sex_label","employee_count","us"]

df = pd.DataFrame(columns=col_names, data=r.json()[1:])

df["sex"] = df["sex"].astype(int)
df["employee_count"] = df["employee_count"].astype(int)
df["us"] = df["us"].astype(int)
df.head()
# gender_employee_counts = df[['sex_label','employee_count']]
# employee_count1 = df['employee_count'].iloc[1:]
# sex_label1 = df['sex_label'].iloc[1:]
# df2 = pd.DataFrame(columns=["sex_label1","employee_count1"])
# df2["employee_count1"] = df2["employee_count1"].astype(int)
# gender_payrolls = df[['sex_label1','employee_count1']]
# gender_employee_counts.plot.bar(x = 'sex_label', y = 'employee_count')
# plt.plot(df['sex_label'],df['annual_payroll'])
# plt.title('Employee Counts for Businesses based on Gender')
# plt.xlabel('Gender')
# plt.ylabel('Employee Count (Scientific Notation)')
# plt.show()

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

HOST = "https://api.census.gov/data"
dataset1 = "2018/abscs?"
parameters1 = "get=GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,VET_GROUP,VET_GROUP_LABEL,EMPSZFI,EMPSZFI_LABEL,YEAR,FIRMPDEMP,FIRMPDEMP_F,RCPPDEMP,RCPPDEMP_F,EMP,EMP_F,PAYANN,PAYANN_F,FIRMPDEMP_S,FIRMPDEMP_S_F,RCPPDEMP_S,RCPPDEMP_S_F,EMP_S,EMP_S_F,PAYANN_S,PAYANN_S_F&for=us:"

base_url = "/".join([HOST, dataset1])

predicates = {}

get_vars = ["PAYANN","EMP"]

predicates['get'] = ",".join(get_vars)
predicates['for'] = "us"
r = requests.get(base_url, params=predicates)

# print(r.text)
# print(r.json()[0])

col_names = ["annual_payroll","employee_count","us"]

df = pd.DataFrame(columns=col_names, data=r.json()[1:])

df["annual_payroll"] = df["annual_payroll"].astype(int)
df["employee_count"] = df["employee_count"].astype(int)
df["us"] = df["us"].astype(int)
print(df.head())
# use seaborn to create a scatter plot

f, ax = plt.subplots(figsize=(6.5, 6.5))

# plt.plot(df['sex_label'],df['annual_payroll'])
plt.title('Employee Counts for Businesses based on Gender')
plt.xlabel('Gender')
plt.ylabel('Employee Count')
plt.show()

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

HOST = "https://api.census.gov/data"
dataset1 = "2018/abscs?"
parameters1 = "get=GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,VET_GROUP,VET_GROUP_LABEL,EMPSZFI,EMPSZFI_LABEL,YEAR,FIRMPDEMP,FIRMPDEMP_F,RCPPDEMP,RCPPDEMP_F,EMP,EMP_F,PAYANN,PAYANN_F,FIRMPDEMP_S,FIRMPDEMP_S_F,RCPPDEMP_S,RCPPDEMP_S_F,EMP_S,EMP_S_F,PAYANN_S,PAYANN_S_F&for=us:"

base_url = "/".join([HOST, dataset1])

predicates = {}

get_vars = ["SEX","SEX_LABEL","RCPPDEMP","PAYANN"]

predicates['get'] = ",".join(get_vars)
predicates['for'] = "us"
r = requests.get(base_url, params=predicates)

# print(r.text)
# print(r.json()[0])

col_names = ["sex_code","sex_label","annual_sales","total_payroll","us"]

df = pd.DataFrame(columns=col_names, data=r.json()[1:])

df["sex_code"] = df["sex_code"].astype(int)
df["annual_sales"] = df["annual_sales"].astype(float)
df["total_payroll"] = df["total_payroll"].astype(float)
df["us"] = df["us"].astype(int)
print(df.head())

# use seaborn
sns.set_theme(style="whitegrid")
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
sns.scatterplot(x="annual_sales", y="total_payroll",palette="ch:r=-.2,d=.3_r",sizes=(1, 8), linewidth=1,
                data=df, ax=ax)

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

HOST = "https://api.census.gov/data"
dataset1 = "2018/abscs?"
parameters1 = "get=GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,VET_GROUP,VET_GROUP_LABEL,EMPSZFI,EMPSZFI_LABEL,YEAR,FIRMPDEMP,FIRMPDEMP_F,RCPPDEMP,RCPPDEMP_F,EMP,EMP_F,PAYANN,PAYANN_F,FIRMPDEMP_S,FIRMPDEMP_S_F,RCPPDEMP_S,RCPPDEMP_S_F,EMP_S,EMP_S_F,PAYANN_S,PAYANN_S_F&for=us:"

base_url = "/".join([HOST, dataset1])

predicates = {}

get_vars = ["SEX","SEX_LABEL","EMP","PAYANN"]

predicates['get'] = ",".join(get_vars)
predicates['for'] = "state:*"
r = requests.get(base_url, params=predicates)

# print(r.text)
# print(r.json()[0])

col_names = ["sex_code","sex_label","employee_count","total_payroll","state"]

df = pd.DataFrame(columns=col_names, data=r.json()[1:])

df["sex_code"] = df["sex_code"].astype(int)
df["employee_count"] = df["employee_count"].astype(int)
df["total_payroll"] = df["total_payroll"].astype(float)
df["state"] = df["state"].astype(int)
print(df.head(10))

# use seaborn
sns.set_theme(style="whitegrid")
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
sns.scatterplot(x="employee_count", y="total_payroll",palette="ch:r=-.2,d=.3_r",sizes=(1, 8), linewidth=1,
                data=df, ax=ax)

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

HOST = "https://api.census.gov/data"
dataset1 = "2018/abscs?"
parameters1 = "get=GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,VET_GROUP,VET_GROUP_LABEL,EMPSZFI,EMPSZFI_LABEL,YEAR,FIRMPDEMP,FIRMPDEMP_F,RCPPDEMP,RCPPDEMP_F,EMP,EMP_F,PAYANN,PAYANN_F,FIRMPDEMP_S,FIRMPDEMP_S_F,RCPPDEMP_S,RCPPDEMP_S_F,EMP_S,EMP_S_F,PAYANN_S,PAYANN_S_F&for=us:"

base_url = "/".join([HOST, dataset1])

predicates = {}

get_vars = ["EMP","PAYANN","NAME","SEX","SEX_LABEL"]

predicates['get'] = ",".join(get_vars)
predicates['for'] = "state:*"
r = requests.get(base_url, params=predicates)

# print(r.text)
# print(r.json()[0])

col_names = ["employee_count","total_payroll","state_name","sex_code","sex_label","state"]

df = pd.DataFrame(columns=col_names, data=r.json()[1:])


df["employee_count"] = df["employee_count"].astype(int)
df["total_payroll"] = df["total_payroll"].astype(float)
df["sex_code"] = df["sex_code"].astype(int)
df["state"] = df["state"].astype(int)
# print(df.head(50))
# use seaborn
sns.set_theme(style="whitegrid")
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
fig = sns.regplot(x="employee_count", y="total_payroll",
                data=df, ax=ax)
fig.set(xlabel='Employee Count (Scientific Notation)', ylabel='Total Payroll (Scientific Notation)',title='Total Payroll in Each State based on the Employee Count')

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

HOST = "https://api.census.gov/data"
dataset1 = "2018/abscs?"
parameters1 = "get=GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,VET_GROUP,VET_GROUP_LABEL,EMPSZFI,EMPSZFI_LABEL,YEAR,FIRMPDEMP,FIRMPDEMP_F,RCPPDEMP,RCPPDEMP_F,EMP,EMP_F,PAYANN,PAYANN_F,FIRMPDEMP_S,FIRMPDEMP_S_F,RCPPDEMP_S,RCPPDEMP_S_F,EMP_S,EMP_S_F,PAYANN_S,PAYANN_S_F&for=us:"

base_url = "/".join([HOST, dataset1])

predicates = {}

get_vars = ["EMP","PAYANN","NAME"]

predicates['get'] = ",".join(get_vars)
predicates['for'] = "state:*"
r = requests.get(base_url, params=predicates)

# print(r.text)
# print(r.json()[0])

col_names = ["employee_count","total_payroll","state_name","state"]

df = pd.DataFrame(columns=col_names, data=r.json()[1:])


df["employee_count"] = df["employee_count"].astype(int)
df["total_payroll"] = df["total_payroll"].astype(int)
df["state"] = df["state"].astype(int)

categories = df[['employee_count','total_payroll','state_name']]

# def divide(x,y):
#     return (x/y)

categories['pay/emp'] = categories['total_payroll']/categories['employee_count']

sorted_1 = categories.sort_values(by=['pay/emp'],ascending = False)
print(categories.head())
top_ten = sorted_1[0:10]
top_ten.head(10)
# print(categories.head())

top_ten.plot.bar(x = 'state_name', y = 'pay/emp')
plt.title('States with the Highest Pay')
plt.xlabel('State')
plt.ylabel('Pay per Employee')
plt.show()

# use seaborn
# sns.set_theme(style="whitegrid")
# f, ax = plt.subplots(figsize=(6.5, 6.5))
# sns.despine(f, left=True, bottom=True)
# fig = sns.scatterplot(x="employee_count", y="total_payroll",
#                 palette="ch:r=-.2,d=.3_r",sizes=(1, 8), linewidth=1,
#                 data=df, ax=ax)
# fig.set(xlabel='Employee Count (Scientific Notation)', ylabel='Total Payroll (Scientific Notation)',title='Total Payroll in Each State based on the Employee Count')

# %%
import plotly.express as px
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

HOST = "https://api.census.gov/data"
dataset1 = "2018/abscs?"
parameters1 = "get=GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,VET_GROUP,VET_GROUP_LABEL,EMPSZFI,EMPSZFI_LABEL,YEAR,FIRMPDEMP,FIRMPDEMP_F,RCPPDEMP,RCPPDEMP_F,EMP,EMP_F,PAYANN,PAYANN_F,FIRMPDEMP_S,FIRMPDEMP_S_F,RCPPDEMP_S,RCPPDEMP_S_F,EMP_S,EMP_S_F,PAYANN_S,PAYANN_S_F&for=us:"

base_url = "/".join([HOST, dataset1])

predicates = {}

get_vars = ["EMP","PAYANN","NAME","SEX","SEX_LABEL"]

predicates['get'] = ",".join(get_vars)
predicates['for'] = "state:*"
r = requests.get(base_url, params=predicates)

# print(r.text)
# print(r.json()[0])

col_names = ["employee_count","total_payroll","state_name","sex_code","sex_label","state"]

df = pd.DataFrame(columns=col_names, data=r.json()[1:])


df["employee_count"] = df["employee_count"].astype(int)
df["total_payroll"] = df["total_payroll"].astype(int)
df["state"] = df["state"].astype(int)

categories = df[['employee_count','total_payroll','state_name','sex_code','sex_label']]

# def divide(x,y):
#     return (x/y)

categories['pay/emp'] = categories['total_payroll']/categories['employee_count']

# sorted_1 = categories.sort_values(by=['pay/emp'],ascending = False)
# print(sorted_1)

dropped_totals = categories[(categories['sex_label'] == 'Male') | (categories['sex_label'] == 'Female')]
# dropped_totals.head()

sorted_2 = dropped_totals.sort_values(by=['pay/emp'],ascending = False)
sorted_2.head(10)
# print(categories.head())
# top_ten = sorted_1[0:10]
# print(top_ten.head())

fig = px.bar(sorted_2, x="state_name", y="pay/emp",color="sex_label",barmode='group',
             labels={
                     "state_name": "State",
                     "pay/emp": "Payroll per Employee",
                     "sex_label": "Gender"
                 },
             title='Payroll per Employee for Male and Female Owned Businesses in All 50 States',height=400)
fig.show()

# df5 = px.top_ten.tips()
# fig = px.bar(df5, x="state_name", y="pay/emp", color="sex_label", barmode="group")
# fig.show()

# %%
import plotly.express as px
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

HOST = "https://api.census.gov/data"
dataset1 = "2018/abscs?"
parameters1 = "get=GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,VET_GROUP,VET_GROUP_LABEL,EMPSZFI,EMPSZFI_LABEL,YEAR,FIRMPDEMP,FIRMPDEMP_F,RCPPDEMP,RCPPDEMP_F,EMP,EMP_F,PAYANN,PAYANN_F,FIRMPDEMP_S,FIRMPDEMP_S_F,RCPPDEMP_S,RCPPDEMP_S_F,EMP_S,EMP_S_F,PAYANN_S,PAYANN_S_F&for=us:"

base_url = "/".join([HOST, dataset1])

predicates = {}

get_vars = ["EMP","PAYANN","NAME","SEX","SEX_LABEL"]

predicates['get'] = ",".join(get_vars)
predicates['for'] = "state:*"
r = requests.get(base_url, params=predicates)

# print(r.text)
# print(r.json()[0])

col_names = ["employee_count","total_payroll","state_name","sex_code","sex_label","state"]

df = pd.DataFrame(columns=col_names, data=r.json()[1:])


df["employee_count"] = df["employee_count"].astype(int)
df["total_payroll"] = df["total_payroll"].astype(int)
df["state"] = df["state"].astype(int)

categories = df[['employee_count','total_payroll','state_name','sex_code','sex_label']]

# def divide(x,y):
#     return (x/y)

categories['pay/emp'] = categories['total_payroll']/categories['employee_count']

# sorted_1 = categories.sort_values(by=['pay/emp'],ascending = False)
# print(sorted_1)

dropped_totals = categories[(categories['sex_label'] == 'Male') | (categories['sex_label'] == 'Female')]
# dropped_totals.head()

sorted_2 = dropped_totals.sort_values(by=['pay/emp'],ascending = False)
sorted_2.head(10)

top_ten = sorted_2[0:10]
# print(categories.head())
# top_ten = sorted_1[0:10]
# print(top_ten.head())

fig = px.bar(top_ten, x="state_name", y="pay/emp",color="sex_label",barmode='group',
             labels={
                     "state_name": "State",
                     "pay/emp": "Payroll per Employee",
                     "sex_label": "Gender"
                 }
             ,title='Top Ten Payrolls per Employee',height=400)
# fig.title('Top 10 Payrolls per Employee')
fig.show()

# df5 = px.top_ten.tips()
# fig = px.bar(df5, x="state_name", y="pay/emp", color="sex_label", barmode="group")
# fig.show()
